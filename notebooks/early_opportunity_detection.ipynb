# %% [markdown]
# # Early Opportunity Detection
#
# Track how a sector or cyclical ETF moves through the opportunity buckets.

# %%
from pathlib import Path
from src.data.loaders import load_config_bundle
from src.orchestrator.run_daily_cycle import DailyCycleRunner

project_root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
config = load_config_bundle(project_root / 'config')
artifacts = DailyCycleRunner(config=config, project_root=project_root).run(run_type='research', persist=False)
artifacts.opportunity_table.head(20)
