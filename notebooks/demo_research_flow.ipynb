# %% [markdown]
# # Demo Research Flow
#
# This notebook runs one end-to-end cycle of the Market Intelligence Engine and previews the main outputs.

# %%
from pathlib import Path
from src.data.loaders import load_config_bundle
from src.orchestrator.run_daily_cycle import DailyCycleRunner

project_root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
config = load_config_bundle(project_root / 'config')
runner = DailyCycleRunner(config=config, project_root=project_root)
artifacts = runner.run()
artifacts.fusion

# %%
artifacts.sector_table.head(10)

# %%
print((project_root / 'outputs' / 'reports' / 'daily_report.md').read_text())
